# %% [markdown]
# # 03 – Feature Engineering
#
# ## Ziel
# Erzeugung neuer Merkmale zur Analyse von Wettbewerb, Effizienz und Digitalisierung.
#
# ## Schritte
# - Competition Index
# - Efficiency Gap
# - SME Participation Rate
# - Digitalization Score
