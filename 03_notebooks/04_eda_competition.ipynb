# %% [markdown]
# # 04 – EDA: Competition
#
# ## Ziel
# Analyse der Wettbewerbsdynamik in EU-Vergaben.
#
# ## Schritte
# - Verteilung der Anzahl der Angebote
# - Wettbewerb nach Ländern
# - Wettbewerb nach CPV-Codes
# - Wettbewerb nach Verfahrenstypen
