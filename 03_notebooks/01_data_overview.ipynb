# %% [markdown]
# # 01 – Data Overview
#
# ## Ziel
# Erster Überblick über die TED-Daten: Struktur, Spalten, Datentypen, grundlegende Statistiken.
#
# ## Schritte
# - Daten laden
# - Spalten anzeigen
# - Datentypen prüfen
# - Fehlende Werte analysieren
# - Erste Hypothesen formulieren
