# %% [markdown]
# # 11 – AI Readiness Score
#
# ## Ziel
# Bewertung der digitalen und KI-Reife von Vergabeverfahren.
#
# ## Schritte
# - Definition des Scores
# - Berechnung
# - Analyse nach Ländern
# - Analyse nach CPV
