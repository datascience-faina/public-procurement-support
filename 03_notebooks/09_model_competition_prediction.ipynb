# %% [markdown]
# # 09 – Model: Competition Prediction
#
# ## Ziel
# Vorhersage der Anzahl der Angebote mittels ML-Modellen.
#
# ## Schritte
# - Feature-Auswahl
# - Modelltraining
# - Evaluation
# - Feature Importance
