# %% [markdown]
# # 05 – EDA: Efficiency
#
# ## Ziel
# Analyse der Effizienz öffentlicher Vergaben.
#
# ## Schritte
# - Vergleich geschätzt vs. tatsächlich
# - Effizienz nach Ländern
# - Effizienz nach CPV
# - Effizienz nach Verfahrenstyp
