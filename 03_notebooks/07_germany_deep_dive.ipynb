# %% [markdown]
# # 07 – Germany Deep Dive
#
# ## Ziel
# Analyse deutscher Vergabeverfahren im Vergleich zum EU-Durchschnitt.
#
# ## Schritte
# - Wettbewerb DE vs EU
# - Effizienz DE vs EU
# - Digitalisierungsgrad DE vs EU
# - Strukturelle Besonderheiten
