# %% [markdown]
# # 06 – EDA: Digitalization
#
# ## Ziel
# Analyse der digitalen Reife europäischer Vergabeverfahren.
#
# ## Schritte
# - Elektronische Angebote
# - Elektronische Auktionen
# - Dynamische Beschaffungssysteme
# - Digitalization Score
