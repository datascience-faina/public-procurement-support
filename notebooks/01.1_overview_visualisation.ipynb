# %% [markdown]
# # Overview - Visualisation
#
# This notebook provides visual exploration of the raw dataset to understand distributions,
# patterns, and relationships between key variables.
#
# ### CONTENT
# - Load the raw dataset from Pickle
# - Visualize distributions of numeric variables (histograms, KDE)
# - Explore categorical variables (bar plots, frequency charts)
# - Examine correlations between numeric variables (heatmap)
# - Plot selected relationships (scatterplots, boxplots)
#  - Highlight visually detectable anomalies or structural patterns
#
# ### GOAL
# Build an intuitive understanding of the dataset through visual inspection before performing outlier analysis and data cleaning.

# %% [markdown]
# --------------------------
#
# ## BASE SETTINGS
#
# ---------------------------

# %%
# ---------------------------------------------------------
# Import moduls
# ---------------------------------------------------------


# import standard modules
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

import sys
from pathlib import Path

# %%
# ---------------------------------------------------------
# Setup style
# ---------------------------------------------------------

# show all columns
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# visualisation settings
pd.set_option('display.float_format', '{:,.2f}'.format)


# seaborn style
sns.set_theme(style="whitegrid")

# %%
# ---------------------------------------------------------
# Load scripts
# ---------------------------------------------------------

# %load_ext autoreload
# %autoreload 2

from pathlib import Path
import sys

# found min directory
PROJECT_ROOT = Path("..").resolve()

# maindirectory sys.path
if str(PROJECT_ROOT) not in sys.path:
    sys.path.insert(0, str(PROJECT_ROOT))

# import function from script
from my_scripts.visualization import (
                                    plot_histograms, plot_bar_top_categories, 
                                    plot_correlation_matrix
                                      )
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
# ---------------------------------------------------------
# Read data
# ---------------------------------------------------------

# read data
df = pd.read_pickle("../data/dataset.pkl")


# selection of numeric columns
numeric_cols = ["VALUE_EURO", "AWARD_VALUE_EURO", "NUMBER_OFFERS", "LOTS_NUMBER"]

df_num = df[numeric_cols].copy()

# %% [markdown]
# --------------------------
#
# ## DATA VISUALISATIONS
#
# ---------------------------

# %%
plot_histograms(df, numeric_cols, save=True)

# %%
plot_correlation_matrix(df, numeric_cols, save=True)

# %%
plot_bar_top_categories(df, "ISO_COUNTRY_CODE", top_n=15, save=True)
